# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('HR Data.csv')

# %%
data.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# check the dimension of the data
data.shape
# Out:
# (1470, 35)

# %%
# check the data type
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
 #### Datatypes are categorical and numerical

# %%
## check 5 point summary 
data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# for categorical variable
data.describe(include='object').T
# Out:
#                count unique                     top  freq
# Attrition       1470      2                      No  1233
# BusinessTravel  1470      3           Travel_Rarely  1043
# Department      1470      3  Research & Development   961
# EducationField  1470      6           Life Sciences   606
# Gender          1470      2                    Male   882
# JobRole         1470      9         Sales Executive   326
# MaritalStatus   1470      3                 Married   673
# Over18          1470      1                       Y  1470
# OverTime        1470      2                      No  1054

# %%
## check the missing value
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
## Inference : There are no missing values in the given dataset

# %%
data.EmployeeCount.value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
data.Over18.value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
data.StandardHours.value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
## 1 . drop the unnecessary columns 
# ['EmployeeCount','Over18','StandardHours'] these are those columns in which all values are same
data.drop(columns=['EmployeeCount','Over18','StandardHours'],inplace=True)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# 2. Giving the columns new names (if needed)
# Example: Let's rename some columns for better clarity
new_names_mapping = {
    'BusinessTravel': 'Business_Travel',
    'EducationField' : 'Education_Field',
    'JobRole' :'JobRole',
    'JobSatisfaction':'JobSatisfaction'}
    
data = data.rename(columns=new_names_mapping)

# %%
## 3.Drop the duplicates values
data = data.drop_duplicates()

# %%
# 4 drop the Nan value
data = data.dropna()

# %%
# 5. Sanitizing specific columns
for column in data.columns:
    # Check if the column is of string type
    if data[column].dtype == 'object':
        # Remove leading and trailing whitespaces from column values
        data[column] = data[column].str.strip()

# %%
# Display the cleaned data
data.head(4)
# Out:
#    Age Attrition    Business_Travel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
#
#    DistanceFromHome  Education Education_Field  EmployeeNumber  \
# 0                 1          2   Life Sciences               1
# 1                 8          1   Life Sciences               2
# 2                 2          2           Other               4
# 3                 3          4   Life Sciences               5
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# 1                        3  ...                 4                         4
# ...

# %% [markdown]
# #### Visualization

# %%
# 1. Histogram of Age distribution
plt.figure(figsize=(8, 6))
sns.histplot(data['Age'], bins=30, kde=True, color='green')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Bar plot of Attrition
plt.figure(figsize=(8, 6))
sns.countplot(x='Attrition', data=data, palette='Set2')
plt.title('Attrition Count')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %%
# 3. Box plot of Monthly Income by Department
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='MonthlyIncome', data=data)
plt.title('Monthly Income by Department')
plt.xlabel('Department')
plt.ylabel('Monthly Income')
plt.show()

# %%
# Visualize all columns
for column in data.columns:
    if data[column].dtype == 'object':
        # Categorical column: create count plot
        plt.figure(figsize=(8, 6))
        sns.countplot(x=column, data=data)
        plt.title(f'{column} Count')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
        plt.show()
    else:
        # Numerical column: create histogram
        plt.figure(figsize=(8, 6))
        sns.histplot(data[column], bins=30, kde=True, color='red')
        plt.title(f'{column} Distribution')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %% [markdown]
# # Inferences :
# 1. Most of employees travel_rarely.
# 2. Daily rate distribution is normally distributed. Means dailyrate range lie in 200 to 1400
# 3. Most of employee work in Research and development
# 4. Distance from home is right skewed means there are more employee work from with large distance
# 5. Education background of the most of employees are Life science and Medical , Marketing.
# 6.  Employee Number is normally distributed. Means employee no in different department lie in range upto 2000
# 7. Most of employee satisfied with their office environment.
# 8. Most of employee are Male than the female.
# 9. Most of Employees work as Sales Executive , Research Scientist , Laboratory Technician .
# 10. Most of employees are Married.
# 11. Employees avoid the overtime work . There are few employees who do overtime work.
